# %%
import json
with open('/home/s6amalia/xlmroberta-xnli-es-log-history.json') as f:
    logs = json.load(f)

# %%
import pandas as pd
df_logs = pd.DataFrame(logs)
df_logs
# Out:
#        loss  learning_rate  epoch    step  eval_loss  eval_runtime  \
# 0    1.0887   9.974536e-06   0.01     500        NaN           NaN
# 1    0.9819   9.949071e-06   0.02    1000        NaN           NaN
# 2    0.8789   9.923607e-06   0.03    1500        NaN           NaN
# 3    0.8205   9.898142e-06   0.04    2000        NaN           NaN
# 4    0.8197   9.872678e-06   0.05    2500        NaN           NaN
# ..      ...            ...    ...     ...        ...           ...
# 392  0.3839   6.885593e-08   3.97  195000        NaN           NaN
# 393  0.3980   4.339146e-08   3.98  195500        NaN           NaN
# 394  0.3879   1.792699e-08   3.99  196000        NaN           NaN
# 395     NaN            NaN   4.00  196352   0.682506        3.0837
# 396     NaN            NaN   4.00  196352        NaN           NaN
#
#      eval_samples_per_second  eval_steps_per_second  train_runtime  \
# 0                        NaN                    NaN            NaN
# ...

# %%
ax=df_logs[['loss','epoch']].dropna().plot(x='epoch',y='loss')
df_logs[['eval_loss','epoch']].dropna().plot(ax=ax,x='epoch',y='eval_loss',style='.-')
# Out:
# <Axes: xlabel='epoch'>
