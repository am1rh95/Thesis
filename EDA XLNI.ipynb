# %%
import pandas as pd
language = 'es'
from datasets import load_dataset
dataset = load_dataset('xnli', split='test',language=language)
df_test = pd.DataFrame(dataset)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 language = 'es'
# ----> 3 from datasets import load_dataset
#       4 dataset = load_dataset('xnli', split='test',language=language)
#       5 df_test = pd.DataFrame(dataset)
#
# File ~/anaconda3/lib/python3.11/site-packages/datasets/__init__.py:43
#      40 del pyarrow
#      41 del version
# ---> 43 from .arrow_dataset import Dataset
#      44 from .arrow_reader import ReadInstruction
#      45 from .builder import ArrowBasedBuilder, BeamBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# File ~/anaconda3/lib/python3.11/site-packages/datasets/arrow_dataset.py:66
#      64 from . import config
#      65 from .arrow_reader import ArrowReader
# ---> 66 from .arrow_writer import ArrowWriter, OptimizedTypedSequence
# ...

# %%
df_test

# %%
df_test.groupby('label').count()
# Out:
#        premise  hypothesis
# label
# 0         1670        1670
# 1         1670        1670
# 2         1670        1670

# %%
import numpy as np
df_counts=pd.Series(np.concatenate([x.split() for x in df_test.premise])).value_counts().head(20)

# %%
ax =df_counts.plot.bar()
ax.set(xlabel="top 20 words in premise", ylabel="count")
# ax.set_xticks(range(len(df_counts)))
# ax.set_xticklabels(["%s" % item for item in df_counts.index.tolist()], rotation=90)
# Out:
# [Text(0.5, 0, 'top 20 words in premise'), Text(0, 0.5, 'count')]

# %%
df_counts=pd.Series(np.concatenate([x.split() for x in df_test.hypothesis])).value_counts().head(20)
ax =df_counts.plot.bar()
ax.set(xlabel="top 20 words in hypothesis", ylabel="count")
# Out:
# [Text(0.5, 0, 'top 20 words in hypothesis'), Text(0, 0.5, 'count')]
